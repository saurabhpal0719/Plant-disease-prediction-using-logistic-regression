# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/plant_disease_synthetic.csv")
df.head()
# Out:
#    Leaf_Color_Intensity  Leaf_Spot_Count  Leaf_Moisture  Temp_Exposure  \
# 0              0.548814                2       0.493770       8.929395
# 1              0.715189                3       0.633141       8.612257
# 2              0.602763                1       0.898413       4.361516
# 3              0.544883                4       0.215931       3.130011
# 4              0.423655                4       0.027821       5.810554
#
#     Humidity  Leaf_Age  Plant_Height   Soil_pH  Nitrogen_Level  \
# 0  66.286642        19     56.110010  6.282655       42.761234
# 1  72.054954        14     30.911319  7.573022       59.787531
# 2  53.382139        16     48.221429  6.714231       20.498300
# 3  54.691162        11     42.903780  7.081108       37.197025
# 4  71.435388        14     54.747749  7.536187       34.076174
#
#    Pesticide_Used  Rainfall  Wind_Speed  Diseased
# 0               1  6.682459   11.152628         1
# 1               0  4.147862    1.733118         1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Leaf_Color_Intensity  5000 non-null   float64
#  1   Leaf_Spot_Count       5000 non-null   int64
#  2   Leaf_Moisture         5000 non-null   float64
#  3   Temp_Exposure         5000 non-null   float64
#  4   Humidity              5000 non-null   float64
#  5   Leaf_Age              5000 non-null   int64
#  6   Plant_Height          5000 non-null   float64
#  7   Soil_pH               5000 non-null   float64
#  8   Nitrogen_Level        5000 non-null   float64
#  9   Pesticide_Used        5000 non-null   int64
#  10  Rainfall              5000 non-null   float64
#  11  Wind_Speed            5000 non-null   float64
#  12  Diseased              5000 non-null   int64
# dtypes: float64(9), int64(4)
# memory usage: 507.9 KB

# %%
df.drop(columns=["Rainfall"],inplace=True)

# %%
df.drop(columns=["Plant_Height"],inplace=True)

# %%
df.head()
# Out:
#    Leaf_Color_Intensity  Leaf_Spot_Count  Leaf_Moisture  Temp_Exposure  \
# 0              0.548814                2       0.493770       8.929395
# 1              0.715189                3       0.633141       8.612257
# 2              0.602763                1       0.898413       4.361516
# 3              0.544883                4       0.215931       3.130011
# 4              0.423655                4       0.027821       5.810554
#
#     Humidity  Leaf_Age   Soil_pH  Nitrogen_Level  Pesticide_Used  Wind_Speed  \
# 0  66.286642        19  6.282655       42.761234               1   11.152628
# 1  72.054954        14  7.573022       59.787531               0    1.733118
# 2  53.382139        16  6.714231       20.498300               1    3.084349
# 3  54.691162        11  7.081108       37.197025               1   14.117084
# 4  71.435388        14  7.536187       34.076174               0   12.428820
#
#    Diseased
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns=["Diseased"])
y = df["Diseased"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(class_weight='balanced')
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(ytest, ypred)
conf_matrix = confusion_matrix(ytest, ypred)
class_report = classification_report(ytest, ypred)

print("Model Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Model Accuracy: 0.981
# Confusion Matrix:
#  [[ 17   0]
#  [ 19 964]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64        17
#            1       1.00      0.98      0.99       983
#
#     accuracy                           0.98      1000
#    macro avg       0.74      0.99      0.82      1000
# weighted avg       0.99      0.98      0.98      1000
